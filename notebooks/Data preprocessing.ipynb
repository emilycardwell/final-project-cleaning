# %%
import pandas as pd

# %% [markdown]
# # Kaggle dataset

# %%
df2 = pd.read_csv('/Users/sammy/Downloads/Chords/archive/chords_and_lyrics.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0    artist_name                        song_name  \
# 0           0  Justin Bieber                     10,000 Hours
# 1           1  Justin Bieber                           2 Much
# 2           2  Justin Bieber          2u (feat. David Guetta)
# 3           3  Justin Bieber             All Around The World
# 4           4  Justin Bieber  All Around The World (acoustic)
#
#                                        chords&lyrics  \
# 0  \nCapo on 3rd fret\n\t  \t\t \r\n\r\nVerse 1:\...
# 1  \n\t  \t\t\r\nIntro: F#m7  D2 \r\n\r\nVerse 1:...
# 2  \n\t  \t\t\r\nEm            D         C       ...
# 3  \nCapo on 4th fret\n\t  \t\t\r\n\r\n \r\n\r\n ...
# 4  \n\t  \t\t\r\n\r\nIntro: Gm - Dm - C - C   x2 ...
#
#                                               chords  \
# 0  {3: 'G             G/B                        ...
# 1  {1: 'Intro: F#m7  D2 ', 4: 'F#m7 ', 8: 'D2 ', ...
# 2  {1: 'Em            D         C               C...
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'song_name', 'chords&lyrics', 'chords',
#        'lyrics', 'tabs', 'lang', 'artist_id', 'followers', 'genres',
#        'popularity', 'name_e_chords'],
#       dtype='object')

# %%
df2['genres'].nunique()
# Out:
# 4781

# %% [markdown]
# ## Do a histogram

# %%
# random song
df2.loc[124592]
# Out:
# Unnamed: 0                                                  124592
# artist_name                                            Ana Nóbrega
# song_name                                           De Tal Maneira
# chords&lyrics    \n\t  \t\tIntro: G  C  Em  D  C  G \r\n\r\n   ...
# chords           {0: '\n\t  \t\tIntro: G  C  Em  D  C  G ', 2: ...
# lyrics           {1: '', 3: 'De uma maneira tal ', 5: 'De um je...
# tabs                                                            {}
# lang                                                            pt
# artist_id                                   5LCTcU1OktZQTuh4LFIdzU
# followers                                                 387854.0
# genres                            ['adoracao', 'brazilian gospel']
# popularity                                                      53
# name_e_chords                                          ana-nóbrega
# Name: 124592, dtype: object

# %%
c = df2.loc[124592, 'chords']

# %%
len(c)
# Out:
# 726

# %%
c
# Out:
# "{0: '\\n\\t  \\t\\tIntro: G  C  Em  D  C  G ', 2: '             G ', 4: '             G ', 6: '           C                    G ', 8: '          G                    G ', 10: '           C                 G ', 13: '         Am7 ', 15: '            G/B ', 17: '           C ', 19: '              D         G   D ', 21: '            Am7 ', 23: '             G/B ', 25: '      C ', 27: ' D ', 30: '          G   D ', 32: '          Em7   D ', 34: '          C             D ', 36: '                 G     D ', 39: '( G ) ', 41: 'Solo Em7  C  Am7  G  D ', 43: 'Am7 ', 45: '     Em7 ', 47: 'Am7 ', 49: '     C          D ', 52: 'Am7 ', 54: '     Em7 ', 56: 'Am7 ', 58: '       C          C         D ', 61: 'Final G  C  Em  D  C  G '}"

# %%
r = c.split()
r
# Out:
# ['{0:',
#  "'\\n\\t",
#  '\\t\\tIntro:',
#  'G',
#  'C',
#  'Em',
#  'D',
#  'C',
#  'G',
#  "',",
#  '2:',
#  "'",
#  'G',
#  "',",
#  '4:',
#  "'",
#  'G',
#  "',",
#  '6:',
#  "'",
#  'C',
#  'G',
#  "',",
#  '8:',
#  "'",
#  'G',
#  'G',
#  "',",
#  '10:',
#  "'",
#  'C',
#  'G',
#  "',",
#  '13:',
#  "'",
#  'Am7',
#  "',",
#  '15:',
#  "'",
#  'G/B',
#  "',",
#  '17:',
#  "'",
#  'C',
#  "',",
#  '19:',
#  "'",
#  'D',
#  'G',
#  'D',
#  "',",
#  '21:',
#  "'",
#  'Am7',
#  "',",
#  '23:',
#  "'",
#  'G/B',
#  "',",
#  '25:',
#  "'",
#  'C',
#  "',",
#  '27:',
#  "'",
#  'D',
#  "',",
#  '30:',
#  "'",
#  'G',
#  'D',
#  "',",
#  '32:',
#  "'",
#  'Em7',
#  'D',
#  "',",
#  '34:',
#  "'",
#  'C',
#  'D',
#  "',",
#  '36:',
#  "'",
#  'G',
#  'D',
#  "',",
#  '39:',
#  "'(",
#  'G',
#  ')',
#  "',",
#  '41:',
#  "'Solo",
#  'Em7',
#  'C',
#  'Am7',
#  'G',
#  'D',
#  "',",
#  '43:',
#  "'Am7",
#  "',",
#  '45:',
#  "'",
#  'Em7',
#  "',",
#  '47:',
#  "'Am7",
#  "',",
#  '49:',
# ...

# %%
list(dict.fromkeys(r))
# Out:
# ['{0:',
#  "'\\n\\t",
#  '\\t\\tIntro:',
#  'G',
#  'C',
#  'Em',
#  'D',
#  "',",
#  '2:',
#  "'",
#  '4:',
#  '6:',
#  '8:',
#  '10:',
#  '13:',
#  'Am7',
#  '15:',
#  'G/B',
#  '17:',
#  '19:',
#  '21:',
#  '23:',
#  '25:',
#  '27:',
#  '30:',
#  '32:',
#  'Em7',
#  '34:',
#  '36:',
#  '39:',
#  "'(",
#  ')',
#  '41:',
#  "'Solo",
#  '43:',
#  "'Am7",
#  '45:',
#  '47:',
#  '49:',
#  '52:',
#  '54:',
#  '56:',
#  '58:',
#  '61:',
#  "'Final",
#  "'}"]

# %%
#ch = list(dict.fromkeys(r))[3:7]
ch = ['G', 'C', 'Em', 'D', 'Am7']
ch
# Out:
# ['G', 'C', 'Em', 'D', 'Am7']

# %%
chords = [chord for chord in r if chord in ch]

# %%
chords
# Out:
# ['G',
#  'C',
#  'Em',
#  'D',
#  'C',
#  'G',
#  'G',
#  'G',
#  'C',
#  'G',
#  'G',
#  'G',
#  'C',
#  'G',
#  'Am7',
#  'C',
#  'D',
#  'G',
#  'D',
#  'Am7',
#  'C',
#  'D',
#  'G',
#  'D',
#  'D',
#  'C',
#  'D',
#  'G',
#  'D',
#  'G',
#  'C',
#  'Am7',
#  'G',
#  'D',
#  'C',
#  'D',
#  'C',
#  'C',
#  'D',
#  'G',
#  'C',
#  'Em',
#  'D',
#  'C',
#  'G']

# %%
import string
letters = list(string.ascii_uppercase)[:7]
letters
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
chords2 = [chord for chord in r if chord[0] in letters]

# %%
len(chords2)
# Out:
# 51

# %%
# Get chords of a song
song = df2.loc[124592, 'chords'] # this is a string
# Convert string to list of strings
song_list = song.split()
# See all the unique values in the list
list(dict.fromkeys(song_list))
# Out:
# ['{0:',
#  "'\\n\\t",
#  '\\t\\tIntro:',
#  'G',
#  'C',
#  'Em',
#  'D',
#  "',",
#  '2:',
#  "'",
#  '4:',
#  '6:',
#  '8:',
#  '10:',
#  '13:',
#  'Am7',
#  '15:',
#  'G/B',
#  '17:',
#  '19:',
#  '21:',
#  '23:',
#  '25:',
#  '27:',
#  '30:',
#  '32:',
#  'Em7',
#  '34:',
#  '36:',
#  '39:',
#  "'(",
#  ')',
#  '41:',
#  "'Solo",
#  '43:',
#  "'Am7",
#  '45:',
#  '47:',
#  '49:',
#  '52:',
#  '54:',
#  '56:',
#  '58:',
#  '61:',
#  "'Final",
#  "'}"]

# %%
# Create a list from A to G
import string
letters = list(string.ascii_uppercase)[:7]
#>>> ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# Get a list of all the chords in the song
chords = [chord for chord in song_list if chord[0] in letters]

# %%
len(chords)
# Out:
# 51

# %%
import itertools
chords_2 = next(zip(*itertools.groupby(chords)))
len(chords_2)
# Out:
# 46

# %%
chords
# Out:
# ['G',
#  'C',
#  'Em',
#  'D',
#  'C',
#  'G',
#  'G',
#  'G',
#  'C',
#  'G',
#  'G',
#  'G',
#  'C',
#  'G',
#  'Am7',
#  'G/B',
#  'C',
#  'D',
#  'G',
#  'D',
#  'Am7',
#  'G/B',
#  'C',
#  'D',
#  'G',
#  'D',
#  'Em7',
#  'D',
#  'C',
#  'D',
#  'G',
#  'D',
#  'G',
#  'Em7',
#  'C',
#  'Am7',
#  'G',
#  'D',
#  'Em7',
#  'C',
#  'D',
#  'Em7',
#  'C',
#  'C',
#  'D',
#  'G',
#  'C',
#  'Em',
#  'D',
#  'C',
#  'G']

# %% [markdown]
# # LSTM Realbook

# %%
with open("/Users/sammy/Downloads/Chords/chord_sentences.txt", "r") as file:
    print(file.readline())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
file.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 file.readline()
#
# ValueError: I/O operation on closed file.

# %%
df = pd.read_csv('/Users/sammy/Downloads/Chords/chord_sentences.txt', sep=' ')
# Out:
# KeyboardInterrupt

# %%
t = "C:maj C:maj C:maj C:maj C:maj C:maj C:maj C:maj G:9 G:9 G:9 G:9 G:9 G:9 G:9 G:9 C:9 C:9 C:9 C:9 C:7 C:7 C:7 C:7 F:maj F:maj F:maj F:maj F:min7 F:min7 F:min7 F:min7 C:maj C:maj C:maj C:maj G:min7 G:min7 G:min7 G:min7 A:7 A:7 A:7 A:7 D:9 D:9 D:9 D:9 G:9 G:9 G:9 G:9 E:min7 E:min7 G:7 G:7 C:maj C:maj C:maj C:maj C:maj C:maj C:maj C:maj A:min7 A:min7 A:min7 A:min7 A:min7 A:min7 A:min7 A:min7 E:min7 E:min7 E:min7 E:min7 E:min7 E:min7 E:min7 E:min7 F:maj7 F:maj7 F:maj7 F:maj7 F:7 F:7 F:7 F:7 C:maj C:maj C:maj C:maj C:maj C:maj C:7 C:7 F:maj F:maj F:maj F:maj F:min7 F:min7 F:min7 F:min7 C:maj C:maj C:maj C:maj A:7 A:7 A:7 A:7 D:7 D:7 D:7 D:7 D:7 D:7 G:7 G:7 C:maj C:maj C:maj C:maj C:maj C:ma
:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'G:9',
#  'G:9',
#  'G:9',
#  'G:9',
#  'G:9',
#  'G:9',
#  'G:9',
#  'G:9',
#  'C:9',
#  'C:9',
#  'C:9',
#  'C:9',
#  'C:7',
#  'C:7',
#  'C:7',
#  'C:7',
#  'F:maj',
#  'F:maj',
#  'F:maj',
#  'F:maj',
#  'F:min7',
#  'F:min7',
#  'F:min7',
#  'F:min7',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'G:min7',
#  'G:min7',
#  'G:min7',
#  'G:min7',
#  'A:7',
#  'A:7',
#  'A:7',
#  'A:7',
#  'D:9',
#  'D:9',
#  'D:9',
#  'D:9',
#  'G:9',
#  'G:9',
#  'G:9',
#  'G:9',
#  'E:min7',
#  'E:min7',
#  'G:7',
#  'G:7',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'C:maj',
#  'A:min7',
#  'A:min7',
#  'A:min7',
#  'A:min7',
#  'A:min7',
#  'A:min7',
#  'A:min7',
#  'A:min7',
#  'E:min7',
#  'E:min7',
#  'E:min7',
#  'E:min7',
#  'E:min7',
#  'E:min7',
#  'E:min7',
#  'E:min7',
#  'F:maj7',
#  'F:maj7',
#  'F:maj7',
#  'F:maj7',
#  'F:7',
#  'F:7',
# ...

# %%
list(dict.fromkeys(l))
# Out:
# ['C:maj',
#  'G:9',
#  'C:9',
#  'C:7',
#  'F:maj',
#  'F:min7',
#  'G:min7',
#  'A:7',
#  'D:9',
#  'E:min7',
#  'G:7',
#  'A:min7',
#  'F:maj7',
#  'F:7',
#  'D:7',
#  '_END_',
#  '_START_',
#  'D#:maj',
#  'A#:7',
#  'G:min',
#  'B:7',
#  'D#:7',
#  'G:maj/5',
#  'G:maj',
#  'A#:7/5',
#  'G:dim',
#  'E:min',
#  'D:min',
#  'D:hdim',
#  'C:maj/5',
#  'E:7',
#  'E:maj',
#  'F#:dim',
#  'C:maj/7',
#  'C:maj/b7',
#  'C:maj7',
#  'D:min7',
#  'G:7(s5,*5)',
#  'D#:dim',
#  'C:maj/3',
#  'C#:dim',
#  'B:hdim',
#  'G:9(s5,*5)',
#  'C:maj7/5',
#  'G:maj(b7,b9,11,13)',
#  'E:7(b9)',
#  'G:maj(b7,9,11,13)',
#  'F:9(s11)',
#  'C:maj6',
#  'A#:9',
#  'C:6(9)',
#  'C:aug',
#  'F:min',
#  'D#:min7',
#  'G#:min7',
#  'D#:maj7',
#  'G#:7',
#  'C#:maj7',
#  'C#:7']

# %% [markdown]
# # YCAC

# %%
df = pd.read_csv('/Users/sammy/Downloads/Chords/YCAC-data-1/HandelSlices.csv')

# %%
df
# Out:
#             offset                                         Chord  \
# 0         0.000000            <music21.chord.Chord A5 F#5 D4 D3>
# 1         0.625000            <music21.chord.Chord F#5 D5 D4 D3>
# 2         1.125000           <music21.chord.Chord C#6 F#5 A5 D5>
# 3         1.333333                   <music21.chord.Chord B5 G5>
# 4         1.375000            <music21.chord.Chord C#6 B5 A5 G5>
# ...            ...                                           ...
# 174743  366.000000  <music21.chord.Chord D4 A4 B-4 F#4 C4 D3 D2>
# 174744  366.125000      <music21.chord.Chord D4 A4 F#4 C4 D3 D2>
# 174745  366.250000   <music21.chord.Chord D4 A4 G4 F#4 C4 D3 D2>
# 174746  366.375000                      <music21.chord.Chord G4>
# 174747  366.500000         <music21.chord.Chord D4 G4 B-3 G2 G1>
#
#              NormalForm   PCsInNormalForm GlobalScaleDegrees  HighestPitch  \
# 0             [0, 4, 7]         [2, 6, 9]          [0, 4, 7]            81
# ...
